# %%
import os
import cv2
import numpy as np
import pandas as pd
from pathlib import Path
import random
import re

# ---------- CONFIGURATION ----------
DATASET_DIR = "synthetic_braille_dataset"
DOT_RADIUS = 5      # radius; diameter ~10 px
D = 10              # dot spacing unit
H = 10              # horizontal gap
V = 8               # vertical gap
PAD = 5             # padding around braille cell

CELL_W = 2*D + H        # 30 px
CELL_H = 3*D + 2*V      # 46 px
IMG_W = CELL_W + 2*PAD  # 40 px
IMG_H = CELL_H + 2*PAD  # 56 px

VARIATIONS_PER_CHAR = 250
os.makedirs(DATASET_DIR, exist_ok=True)

# ---------- BRAILLE BIT UTILS ----------
def dots_to_bit(dots):
    bit = 0
    for d in dots:
        bit |= 1 << (d - 1)
    return bit

# ---------- TRANSLITERATION HELPER ----------
def safe_filename(text):
    mapping = {
        "अ": "a", "आ": "aa", "इ": "i", "ई": "ii", "उ": "u", "ऊ": "uu",
        "ए": "e", "ऐ": "ai", "ओ": "o", "औ": "au", "अं": "am", "अः": "ah",
        "क": "ka", "ख": "kha", "ग": "ga", "घ": "gha", "ङ": "nga",
        "च": "cha", "छ": "chha", "ज": "ja", "झ": "jha", "ञ": "nya",
        "ट": "ta", "ठ": "tha", "ड": "da", "ढ": "dha", "ण": "na",
        "त": "ta2", "थ": "tha2", "द": "da2", "ध": "dha2", "न": "na2",
        "प": "pa", "फ": "pha", "ब": "ba", "भ": "bha", "म": "ma",
        "य": "ya", "र": "ra", "ल": "la", "व": "va", "श": "sha",
        "ष": "shha", "स": "sa", "ह": "ha", "क्ष": "ksha", "ज्ञ": "gya",
    }
    text = mapping.get(text, text)
    return re.sub(r'[^a-zA-Z0-9_-]', '_', text)

# ---------- BRAILLE MAP ----------
braille_map = {
    dots_to_bit([1]): 'अ',
    dots_to_bit([3, 4, 5]): 'आ',
    dots_to_bit([2, 4]): 'इ',
    dots_to_bit([3, 5]): 'ई',
    dots_to_bit([1, 3, 6]): 'उ',
    dots_to_bit([1, 2, 5, 6]): 'ऊ',
    dots_to_bit([1, 5]): 'ए',
    dots_to_bit([3, 4]): 'ऐ',
    dots_to_bit([1, 3, 5]): 'ओ',
    dots_to_bit([2, 4, 6]): 'औ',
    dots_to_bit([5, 6]): 'अं',
    dots_to_bit([6]): 'अः',
    dots_to_bit([1, 3]): 'क',
    dots_to_bit([4, 6]): 'ख',
    dots_to_bit([1, 2, 4, 5]): 'ग',
    dots_to_bit([1, 2, 6]): 'घ',
    dots_to_bit([3, 4, 6]): 'ङ',
    dots_to_bit([1, 4]): 'च',
    dots_to_bit([1, 6]): 'छ',
    dots_to_bit([2, 4, 5]): 'ज',
    dots_to_bit([3, 5, 6]): 'झ',
    dots_to_bit([2, 5]): 'ञ',
    dots_to_bit([2, 3, 4, 5, 6]): 'ट',
    dots_to_bit([2, 4, 5, 6]): 'ठ',
    dots_to_bit([1, 2, 4, 6]): 'ड',
    dots_to_bit([1, 2, 3, 4, 5, 6]): 'ढ',
    dots_to_bit([3, 4, 5, 6]): 'ण',
    dots_to_bit([2, 3, 4, 5]): 'त',
    dots_to_bit([1, 4, 5, 6]): 'थ',
    dots_to_bit([1, 4, 5]): 'द',
    dots_to_bit([2, 3, 4, 6]): 'ध',
    dots_to_bit([1, 3, 4, 5]): 'न',
    dots_to_bit([1, 2, 3, 4]): 'प',
    dots_to_bit([2, 3, 5]): 'फ',
    dots_to_bit([1, 2]): 'ब',
    dots_to_bit([4, 5]): 'भ',
    dots_to_bit([1, 3, 4]): 'म',
    dots_to_bit([1, 3, 4, 5, 6]): 'य',
    dots_to_bit([1, 2, 3, 5]): 'र',
    dots_to_bit([1, 2, 3]): 'ल',
    dots_to_bit([1, 2, 3, 6]): 'व',
    dots_to_bit([1, 4, 6]): 'श',
    dots_to_bit([1, 2, 3, 4, 6]): 'ष',
    dots_to_bit([2, 3, 4]): 'स',
    dots_to_bit([1, 2, 5]): 'ह',
    dots_to_bit([1, 2, 3, 4, 5]): 'क्ष',
    dots_to_bit([1, 5, 6]): 'ज्ञ',
}

# ---------- DRAW BRAILLE ----------
def draw_braille_cell(dots_bit):
    img = np.full((IMG_H, IMG_W), 255, np.uint8)

    offset_x = PAD
    offset_y = PAD
    R = DOT_RADIUS

    dot_positions = {
        1: (offset_x + 0,         offset_y + 0),
        2: (offset_x + 0,         offset_y + D + V),
        3: (offset_x + 0,         offset_y + 2*(D + V)),
        4: (offset_x + D + H,     offset_y + 0),
        5: (offset_x + D + H,     offset_y + D + V),
        6: (offset_x + D + H,     offset_y + 2*(D + V)),
    }

    for i in range(1,7):
        x, y = dot_positions[i]
        color = 70 if dots_bit & (1 << (i - 1)) else 235 
        cv2.circle(img, (x, y), R, (color,), -1)

    return img

# ---------- AUGMENTATION ----------
def augment_image(img):
    # Convert to float for better manipulation
    img = img.astype(np.float32)

    # Brightness/contrast adjustment
    img = img * random.uniform(0.7, 1.3) + random.uniform(-20, 20)
    img = np.clip(img, 0, 255).astype(np.uint8)

    # Apply Gaussian blur sometimes
    if random.random() < 0.5:
        k = random.choice([3, 5])
        img = cv2.GaussianBlur(img, (k, k), 0)

    # Add noise to the image
    if random.random() < 0.7:  # 70% chance of noise
        noise = np.random.normal(0, random.randint(3, 12), img.shape)
        img = np.clip(img + noise, 0, 255).astype(np.uint8)

    # ---------- APPLY RANDOM ROTATION ----------
    # 50% chance of having a rotation, 50% will stay straight
    if random.random() < 0.5:
        # Get the image center
        (h, w) = img.shape[:2]
        center = (w // 2, h // 2)

        # Random angle between -5 and +5 degrees (small tilt)
        angle = random.uniform(-5, 5)  # degrees

        # Rotation matrix
        M = cv2.getRotationMatrix2D(center, angle, 1.0)

        # Apply the rotation using the rotation matrix
        img = cv2.warpAffine(img, M, (w, h), flags=cv2.INTER_LINEAR)

    return img
# ---------- GENERATE SYNTHETIC DATA ----------
rows = []
for bits, char in braille_map.items():
    latin = safe_filename(char)
    char_dir = Path(DATASET_DIR) / latin
    char_dir.mkdir(parents=True, exist_ok=True)

    for i in range(VARIATIONS_PER_CHAR):
        img = draw_braille_cell(bits)
        img = augment_image(img)
        fname = f"{latin}_{i:03d}.png"
        path = char_dir / fname
        cv2.imwrite(str(path), img)
        rows.append({
            "filename": str(path),
            "char": char,
            "latin": latin,
            "bits": bits
        })

df = pd.DataFrame(rows)
df.to_csv(Path(DATASET_DIR) / "labels.csv", index=False, encoding="utf-8-sig")
print(f"✅ Generated {len(df)} images in '{DATASET_DIR}'")
# Out:
# ✅ Generated 11750 images in 'synthetic_braille_dataset'

# %%
import pandas as pd
import os
import cv2

# Paths
csv_file = "synthetic_braille_dataset\labels-1.csv"
# csv_file_2 = "synthetic_braille_dataset\labels-1.csv"
images_dir = "synthetic_braille_dataset"
labels_dir = "synthetic_braille_dataset\labels_yolo"

os.makedirs(labels_dir, exist_ok=True)

# Map characters to class IDs
chars = sorted(pd.read_csv(csv_file)['char'].unique())
char2id = {c: i for i, c in enumerate(chars)}

df = pd.read_csv(csv_file)

for _, row in df.iterrows():
    filename = row['filename']
    char = row['char']
    # img_path = os.path.join(images_dir, filename)
    
    # img = cv2.imread(img_path)
    # h, w = img.shape[:2]

    # Assume the whole image is the Braille cell (or you can compute actual bbox if you have bit info)
    x_center = 0.5
    y_center = 0.5
    width = 1.0
    height = 1.0

    class_id = char2id[char]
    label_path = os.path.join(labels_dir, filename.replace('synthetic_braille_dataset','').replace('.png', '.txt').replace('.jpg','.txt'))

    
    with open(label_path, 'w') as f:
        f.write(f"{class_id} {x_center} {y_center} {width} {height}\n")

# %%
import os
import shutil
import csv

# Path to the CSV file
csv_file = r'synthetic_braille_dataset\labels.csv'

# Target folder where you want to move the images
target_folder = r'synthetic_braille_dataset/images'

# Create the target folder if it doesn't exist
os.makedirs(target_folder, exist_ok=True)

# Open and read the CSV file
with open(csv_file, mode='r', newline='', encoding='utf-8-sig') as file:  # utf-8-sig handles BOM
    reader = csv.DictReader(file)
    
    # Iterate through each row in the CSV
    for row in reader:
        png_file_path = os.path.normpath(row['filename'])  # Normalize path from CSV
        
        # Check if the file exists
        if os.path.exists(png_file_path):
            file_name = os.path.basename(png_file_path)
            target_path = os.path.join(target_folder, file_name)
            
            shutil.move(png_file_path, target_path)
            print(f"Moved {file_name} to {target_folder}")
        else:
            print(f"File {png_file_path} not found.")
# Out:
# Moved a_000.png to synthetic_braille_dataset/images
# Moved a_001.png to synthetic_braille_dataset/images
# Moved a_002.png to synthetic_braille_dataset/images
# Moved a_003.png to synthetic_braille_dataset/images
# Moved a_004.png to synthetic_braille_dataset/images
# Moved a_005.png to synthetic_braille_dataset/images
# Moved a_006.png to synthetic_braille_dataset/images
# Moved a_007.png to synthetic_braille_dataset/images
# Moved a_008.png to synthetic_braille_dataset/images
# Moved a_009.png to synthetic_braille_dataset/images
# Moved a_010.png to synthetic_braille_dataset/images
# Moved a_011.png to synthetic_braille_dataset/images
# Moved a_012.png to synthetic_braille_dataset/images
# Moved a_013.png to synthetic_braille_dataset/images
# Moved a_014.png to synthetic_braille_dataset/images
# Moved a_015.png to synthetic_braille_dataset/images
# Moved a_016.png to synthetic_braille_dataset/images
# Moved a_017.png to synthetic_braille_dataset/images
# Moved a_018.png to synthetic_braille_dataset/images
# Moved a_019.png to synthetic_braille_dataset/images
# Moved a_020.png to synthetic_braille_dataset/images
# Moved a_021.png to synthetic_braille_dataset/images
# Moved a_022.png to synthetic_braille_dataset/images
# Moved a_023.png to synthetic_braille_dataset/images
# Moved a_024.png to synthetic_braille_dataset/images
# Moved a_025.png to synthetic_braille_dataset/images
# Moved a_026.png to synthetic_braille_dataset/images
# Moved a_027.png to synthetic_braille_dataset/images
# Moved a_028.png to synthetic_braille_dataset/images
# Moved a_029.png to synthetic_braille_dataset/images
# Moved a_030.png to synthetic_braille_dataset/images
# Moved a_031.png to synthetic_braille_dataset/images
# Moved a_032.png to synthetic_braille_dataset/images
# Moved a_033.png to synthetic_braille_dataset/images
# Moved a_034.png to synthetic_braille_dataset/images
# Moved a_035.png to synthetic_braille_dataset/images
# Moved a_036.png to synthetic_braille_dataset/images
# Moved a_037.png to synthetic_braille_dataset/images
# Moved a_038.png to synthetic_braille_dataset/images
# Moved a_039.png to synthetic_braille_dataset/images
# Moved a_040.png to synthetic_braille_dataset/images
# Moved a_041.png to synthetic_braille_dataset/images
# Moved a_042.png to synthetic_braille_dataset/images
# Moved a_043.png to synthetic_braille_dataset/images
# Moved a_044.png to synthetic_braille_dataset/images
# Moved a_045.png to synthetic_braille_dataset/images
# Moved a_046.png to synthetic_braille_dataset/images
# Moved a_047.png to synthetic_braille_dataset/images
# Moved a_048.png to synthetic_braille_dataset/images
# Moved a_049.png to synthetic_braille_dataset/images
# Moved a_050.png to synthetic_braille_dataset/images
# Moved a_051.png to synthetic_braille_dataset/images
# Moved a_052.png to synthetic_braille_dataset/images
# Moved a_053.png to synthetic_braille_dataset/images
# Moved a_054.png to synthetic_braille_dataset/images
# Moved a_055.png to synthetic_braille_dataset/images
# Moved a_056.png to synthetic_braille_dataset/images
# Moved a_057.png to synthetic_braille_dataset/images
# Moved a_058.png to synthetic_braille_dataset/images
# Moved a_059.png to synthetic_braille_dataset/images
# Moved a_060.png to synthetic_braille_dataset/images
# Moved a_061.png to synthetic_braille_dataset/images
# Moved a_062.png to synthetic_braille_dataset/images
# Moved a_063.png to synthetic_braille_dataset/images
# Moved a_064.png to synthetic_braille_dataset/images
# Moved a_065.png to synthetic_braille_dataset/images
# Moved a_066.png to synthetic_braille_dataset/images
# Moved a_067.png to synthetic_braille_dataset/images
# Moved a_068.png to synthetic_braille_dataset/images
# Moved a_069.png to synthetic_braille_dataset/images
# Moved a_070.png to synthetic_braille_dataset/images
# Moved a_071.png to synthetic_braille_dataset/images
# Moved a_072.png to synthetic_braille_dataset/images
# Moved a_073.png to synthetic_braille_dataset/images
# Moved a_074.png to synthetic_braille_dataset/images
# Moved a_075.png to synthetic_braille_dataset/images
# Moved a_076.png to synthetic_braille_dataset/images
# Moved a_077.png to synthetic_braille_dataset/images
# Moved a_078.png to synthetic_braille_dataset/images
# Moved a_079.png to synthetic_braille_dataset/images
# Moved a_080.png to synthetic_braille_dataset/images
# Moved a_081.png to synthetic_braille_dataset/images
# Moved a_082.png to synthetic_braille_dataset/images
# Moved a_083.png to synthetic_braille_dataset/images
# Moved a_084.png to synthetic_braille_dataset/images
# Moved a_085.png to synthetic_braille_dataset/images
# Moved a_086.png to synthetic_braille_dataset/images
# Moved a_087.png to synthetic_braille_dataset/images
# Moved a_088.png to synthetic_braille_dataset/images
# Moved a_089.png to synthetic_braille_dataset/images
# Moved a_090.png to synthetic_braille_dataset/images
# Moved a_091.png to synthetic_braille_dataset/images
# Moved a_092.png to synthetic_braille_dataset/images
# Moved a_093.png to synthetic_braille_dataset/images
# Moved a_094.png to synthetic_braille_dataset/images
# Moved a_095.png to synthetic_braille_dataset/images
# Moved a_096.png to synthetic_braille_dataset/images
# Moved a_097.png to synthetic_braille_dataset/images
# Moved a_098.png to synthetic_braille_dataset/images
# Moved a_099.png to synthetic_braille_dataset/images
# Moved a_100.png to synthetic_braille_dataset/images
# Moved a_101.png to synthetic_braille_dataset/images
# Moved a_102.png to synthetic_braille_dataset/images
# Moved a_103.png to synthetic_braille_dataset/images
# Moved a_104.png to synthetic_braille_dataset/images
# Moved a_105.png to synthetic_braille_dataset/images
# Moved a_106.png to synthetic_braille_dataset/images
# Moved a_107.png to synthetic_braille_dataset/images
# Moved a_108.png to synthetic_braille_dataset/images
# Moved a_109.png to synthetic_braille_dataset/images
# Moved a_110.png to synthetic_braille_dataset/images
# Moved a_111.png to synthetic_braille_dataset/images
# Moved a_112.png to synthetic_braille_dataset/images
# Moved a_113.png to synthetic_braille_dataset/images
# Moved a_114.png to synthetic_braille_dataset/images
# Moved a_115.png to synthetic_braille_dataset/images
# Moved a_116.png to synthetic_braille_dataset/images
# Moved a_117.png to synthetic_braille_dataset/images
# Moved a_118.png to synthetic_braille_dataset/images
# Moved a_119.png to synthetic_braille_dataset/images
# Moved a_120.png to synthetic_braille_dataset/images
# Moved a_121.png to synthetic_braille_dataset/images
# Moved a_122.png to synthetic_braille_dataset/images
# Moved a_123.png to synthetic_braille_dataset/images
# Moved a_124.png to synthetic_braille_dataset/images
# Moved a_125.png to synthetic_braille_dataset/images
# Moved a_126.png to synthetic_braille_dataset/images
# Moved a_127.png to synthetic_braille_dataset/images
# Moved a_128.png to synthetic_braille_dataset/images
# Moved a_129.png to synthetic_braille_dataset/images
# Moved a_130.png to synthetic_braille_dataset/images
# Moved a_131.png to synthetic_braille_dataset/images
# Moved a_132.png to synthetic_braille_dataset/images
# Moved a_133.png to synthetic_braille_dataset/images
# Moved a_134.png to synthetic_braille_dataset/images
# Moved a_135.png to synthetic_braille_dataset/images
# Moved a_136.png to synthetic_braille_dataset/images
# Moved a_137.png to synthetic_braille_dataset/images
# Moved a_138.png to synthetic_braille_dataset/images
# Moved a_139.png to synthetic_braille_dataset/images
# Moved a_140.png to synthetic_braille_dataset/images
# Moved a_141.png to synthetic_braille_dataset/images
# Moved a_142.png to synthetic_braille_dataset/images
# Moved a_143.png to synthetic_braille_dataset/images
# Moved a_144.png to synthetic_braille_dataset/images
# Moved a_145.png to synthetic_braille_dataset/images
# Moved a_146.png to synthetic_braille_dataset/images
# Moved a_147.png to synthetic_braille_dataset/images
# Moved a_148.png to synthetic_braille_dataset/images
# Moved a_149.png to synthetic_braille_dataset/images
# Moved a_150.png to synthetic_braille_dataset/images
# Moved a_151.png to synthetic_braille_dataset/images
# Moved a_152.png to synthetic_braille_dataset/images
# Moved a_153.png to synthetic_braille_dataset/images
# Moved a_154.png to synthetic_braille_dataset/images
# Moved a_155.png to synthetic_braille_dataset/images
# Moved a_156.png to synthetic_braille_dataset/images
# Moved a_157.png to synthetic_braille_dataset/images
# Moved a_158.png to synthetic_braille_dataset/images
# Moved a_159.png to synthetic_braille_dataset/images
# Moved a_160.png to synthetic_braille_dataset/images
# Moved a_161.png to synthetic_braille_dataset/images
# Moved a_162.png to synthetic_braille_dataset/images
# Moved a_163.png to synthetic_braille_dataset/images
# Moved a_164.png to synthetic_braille_dataset/images
# Moved a_165.png to synthetic_braille_dataset/images
# Moved a_166.png to synthetic_braille_dataset/images
# Moved a_167.png to synthetic_braille_dataset/images
# Moved a_168.png to synthetic_braille_dataset/images
# Moved a_169.png to synthetic_braille_dataset/images
# Moved a_170.png to synthetic_braille_dataset/images
# Moved a_171.png to synthetic_braille_dataset/images
# Moved a_172.png to synthetic_braille_dataset/images
# Moved a_173.png to synthetic_braille_dataset/images
# Moved a_174.png to synthetic_braille_dataset/images
# Moved a_175.png to synthetic_braille_dataset/images
# Moved a_176.png to synthetic_braille_dataset/images
# Moved a_177.png to synthetic_braille_dataset/images
# Moved a_178.png to synthetic_braille_dataset/images
# Moved a_179.png to synthetic_braille_dataset/images
# Moved a_180.png to synthetic_braille_dataset/images
# Moved a_181.png to synthetic_braille_dataset/images
# Moved a_182.png to synthetic_braille_dataset/images
# Moved a_183.png to synthetic_braille_dataset/images
# Moved a_184.png to synthetic_braille_dataset/images
# Moved a_185.png to synthetic_braille_dataset/images
# Moved a_186.png to synthetic_braille_dataset/images
# Moved a_187.png to synthetic_braille_dataset/images
# Moved a_188.png to synthetic_braille_dataset/images
# Moved a_189.png to synthetic_braille_dataset/images
# Moved a_190.png to synthetic_braille_dataset/images
# Moved a_191.png to synthetic_braille_dataset/images
# Moved a_192.png to synthetic_braille_dataset/images
# Moved a_193.png to synthetic_braille_dataset/images
# Moved a_194.png to synthetic_braille_dataset/images
# Moved a_195.png to synthetic_braille_dataset/images
# Moved a_196.png to synthetic_braille_dataset/images
# Moved a_197.png to synthetic_braille_dataset/images
# Moved a_198.png to synthetic_braille_dataset/images
# Moved a_199.png to synthetic_braille_dataset/images
# Moved a_200.png to synthetic_braille_dataset/images
# Moved a_201.png to synthetic_braille_dataset/images
# Moved a_202.png to synthetic_braille_dataset/images
# Moved a_203.png to synthetic_braille_dataset/images
# Moved a_204.png to synthetic_braille_dataset/images
# Moved a_205.png to synthetic_braille_dataset/images
# Moved a_206.png to synthetic_braille_dataset/images
# Moved a_207.png to synthetic_braille_dataset/images
# Moved a_208.png to synthetic_braille_dataset/images
# Moved a_209.png to synthetic_braille_dataset/images
# Moved a_210.png to synthetic_braille_dataset/images
# Moved a_211.png to synthetic_braille_dataset/images
# Moved a_212.png to synthetic_braille_dataset/images
# Moved a_213.png to synthetic_braille_dataset/images
# Moved a_214.png to synthetic_braille_dataset/images
# Moved a_215.png to synthetic_braille_dataset/images
# Moved a_216.png to synthetic_braille_dataset/images
# Moved a_217.png to synthetic_braille_dataset/images
# Moved a_218.png to synthetic_braille_dataset/images
# Moved a_219.png to synthetic_braille_dataset/images
# Moved a_220.png to synthetic_braille_dataset/images
# Moved a_221.png to synthetic_braille_dataset/images
# Moved a_222.png to synthetic_braille_dataset/images
# Moved a_223.png to synthetic_braille_dataset/images
# Moved a_224.png to synthetic_braille_dataset/images
# Moved a_225.png to synthetic_braille_dataset/images
# Moved a_226.png to synthetic_braille_dataset/images
# Moved a_227.png to synthetic_braille_dataset/images
# Moved a_228.png to synthetic_braille_dataset/images
# Moved a_229.png to synthetic_braille_dataset/images
# Moved a_230.png to synthetic_braille_dataset/images
# Moved a_231.png to synthetic_braille_dataset/images
# Moved a_232.png to synthetic_braille_dataset/images
# Moved a_233.png to synthetic_braille_dataset/images
# Moved a_234.png to synthetic_braille_dataset/images
# Moved a_235.png to synthetic_braille_dataset/images
# Moved a_236.png to synthetic_braille_dataset/images
# Moved a_237.png to synthetic_braille_dataset/images
# Moved a_238.png to synthetic_braille_dataset/images
# Moved a_239.png to synthetic_braille_dataset/images
# Moved a_240.png to synthetic_braille_dataset/images
# Moved a_241.png to synthetic_braille_dataset/images
# Moved a_242.png to synthetic_braille_dataset/images
# Moved a_243.png to synthetic_braille_dataset/images
# Moved a_244.png to synthetic_braille_dataset/images
# Moved a_245.png to synthetic_braille_dataset/images
# Moved a_246.png to synthetic_braille_dataset/images
# Moved a_247.png to synthetic_braille_dataset/images
# Moved a_248.png to synthetic_braille_dataset/images
# Moved a_249.png to synthetic_braille_dataset/images
# Moved aa_000.png to synthetic_braille_dataset/images
# Moved aa_001.png to synthetic_braille_dataset/images
# Moved aa_002.png to synthetic_braille_dataset/images
# Moved aa_003.png to synthetic_braille_dataset/images
# Moved aa_004.png to synthetic_braille_dataset/images
# Moved aa_005.png to synthetic_braille_dataset/images
# Moved aa_006.png to synthetic_braille_dataset/images
# Moved aa_007.png to synthetic_braille_dataset/images
# Moved aa_008.png to synthetic_braille_dataset/images
# Moved aa_009.png to synthetic_braille_dataset/images
# Moved aa_010.png to synthetic_braille_dataset/images
# Moved aa_011.png to synthetic_braille_dataset/images
# Moved aa_012.png to synthetic_braille_dataset/images
# Moved aa_013.png to synthetic_braille_dataset/images
# Moved aa_014.png to synthetic_braille_dataset/images
# Moved aa_015.png to synthetic_braille_dataset/images
# Moved aa_016.png to synthetic_braille_dataset/images
# Moved aa_017.png to synthetic_braille_dataset/images
# Moved aa_018.png to synthetic_braille_dataset/images
# Moved aa_019.png to synthetic_braille_dataset/images
# Moved aa_020.png to synthetic_braille_dataset/images
# Moved aa_021.png to synthetic_braille_dataset/images
# Moved aa_022.png to synthetic_braille_dataset/images
# Moved aa_023.png to synthetic_braille_dataset/images
# Moved aa_024.png to synthetic_braille_dataset/images
# Moved aa_025.png to synthetic_braille_dataset/images
# Moved aa_026.png to synthetic_braille_dataset/images
# Moved aa_027.png to synthetic_braille_dataset/images
# Moved aa_028.png to synthetic_braille_dataset/images
# Moved aa_029.png to synthetic_braille_dataset/images
# Moved aa_030.png to synthetic_braille_dataset/images
# Moved aa_031.png to synthetic_braille_dataset/images
# Moved aa_032.png to synthetic_braille_dataset/images
# Moved aa_033.png to synthetic_braille_dataset/images
# Moved aa_034.png to synthetic_braille_dataset/images
# Moved aa_035.png to synthetic_braille_dataset/images
# Moved aa_036.png to synthetic_braille_dataset/images
# Moved aa_037.png to synthetic_braille_dataset/images
# Moved aa_038.png to synthetic_braille_dataset/images
# Moved aa_039.png to synthetic_braille_dataset/images
# Moved aa_040.png to synthetic_braille_dataset/images
# Moved aa_041.png to synthetic_braille_dataset/images
# Moved aa_042.png to synthetic_braille_dataset/images
# Moved aa_043.png to synthetic_braille_dataset/images
# Moved aa_044.png to synthetic_braille_dataset/images
# Moved aa_045.png to synthetic_braille_dataset/images
# Moved aa_046.png to synthetic_braille_dataset/images
# Moved aa_047.png to synthetic_braille_dataset/images
# Moved aa_048.png to synthetic_braille_dataset/images
# Moved aa_049.png to synthetic_braille_dataset/images
# Moved aa_050.png to synthetic_braille_dataset/images
# Moved aa_051.png to synthetic_braille_dataset/images
# Moved aa_052.png to synthetic_braille_dataset/images
# Moved aa_053.png to synthetic_braille_dataset/images
# Moved aa_054.png to synthetic_braille_dataset/images
# Moved aa_055.png to synthetic_braille_dataset/images
# Moved aa_056.png to synthetic_braille_dataset/images
# Moved aa_057.png to synthetic_braille_dataset/images
# Moved aa_058.png to synthetic_braille_dataset/images
# Moved aa_059.png to synthetic_braille_dataset/images
# Moved aa_060.png to synthetic_braille_dataset/images
# Moved aa_061.png to synthetic_braille_dataset/images
# Moved aa_062.png to synthetic_braille_dataset/images
# Moved aa_063.png to synthetic_braille_dataset/images
# Moved aa_064.png to synthetic_braille_dataset/images
# Moved aa_065.png to synthetic_braille_dataset/images
# Moved aa_066.png to synthetic_braille_dataset/images
# Moved aa_067.png to synthetic_braille_dataset/images
# Moved aa_068.png to synthetic_braille_dataset/images
# Moved aa_069.png to synthetic_braille_dataset/images
# Moved aa_070.png to synthetic_braille_dataset/images
# Moved aa_071.png to synthetic_braille_dataset/images
# Moved aa_072.png to synthetic_braille_dataset/images
# Moved aa_073.png to synthetic_braille_dataset/images
# Moved aa_074.png to synthetic_braille_dataset/images
# Moved aa_075.png to synthetic_braille_dataset/images
# Moved aa_076.png to synthetic_braille_dataset/images
# Moved aa_077.png to synthetic_braille_dataset/images
# Moved aa_078.png to synthetic_braille_dataset/images
# Moved aa_079.png to synthetic_braille_dataset/images
# Moved aa_080.png to synthetic_braille_dataset/images
# Moved aa_081.png to synthetic_braille_dataset/images
# Moved aa_082.png to synthetic_braille_dataset/images
# Moved aa_083.png to synthetic_braille_dataset/images
# Moved aa_084.png to synthetic_braille_dataset/images
# Moved aa_085.png to synthetic_braille_dataset/images
# Moved aa_086.png to synthetic_braille_dataset/images
# Moved aa_087.png to synthetic_braille_dataset/images
# Moved aa_088.png to synthetic_braille_dataset/images
# Moved aa_089.png to synthetic_braille_dataset/images
# Moved aa_090.png to synthetic_braille_dataset/images
# Moved aa_091.png to synthetic_braille_dataset/images
# Moved aa_092.png to synthetic_braille_dataset/images
# Moved aa_093.png to synthetic_braille_dataset/images
# Moved aa_094.png to synthetic_braille_dataset/images
# Moved aa_095.png to synthetic_braille_dataset/images
# Moved aa_096.png to synthetic_braille_dataset/images
# Moved aa_097.png to synthetic_braille_dataset/images
# Moved aa_098.png to synthetic_braille_dataset/images
# Moved aa_099.png to synthetic_braille_dataset/images
# Moved aa_100.png to synthetic_braille_dataset/images
# Moved aa_101.png to synthetic_braille_dataset/images
# Moved aa_102.png to synthetic_braille_dataset/images
# Moved aa_103.png to synthetic_braille_dataset/images
# Moved aa_104.png to synthetic_braille_dataset/images
# Moved aa_105.png to synthetic_braille_dataset/images
# Moved aa_106.png to synthetic_braille_dataset/images
# Moved aa_107.png to synthetic_braille_dataset/images
# Moved aa_108.png to synthetic_braille_dataset/images
# Moved aa_109.png to synthetic_braille_dataset/images
# Moved aa_110.png to synthetic_braille_dataset/images
# Moved aa_111.png to synthetic_braille_dataset/images
# Moved aa_112.png to synthetic_braille_dataset/images
# Moved aa_113.png to synthetic_braille_dataset/images
# Moved aa_114.png to synthetic_braille_dataset/images
# Moved aa_115.png to synthetic_braille_dataset/images
# Moved aa_116.png to synthetic_braille_dataset/images
# Moved aa_117.png to synthetic_braille_dataset/images
# Moved aa_118.png to synthetic_braille_dataset/images
# Moved aa_119.png to synthetic_braille_dataset/images
# Moved aa_120.png to synthetic_braille_dataset/images
# Moved aa_121.png to synthetic_braille_dataset/images
# Moved aa_122.png to synthetic_braille_dataset/images
# Moved aa_123.png to synthetic_braille_dataset/images
# Moved aa_124.png to synthetic_braille_dataset/images
# Moved aa_125.png to synthetic_braille_dataset/images
# Moved aa_126.png to synthetic_braille_dataset/images
# Moved aa_127.png to synthetic_braille_dataset/images
# Moved aa_128.png to synthetic_braille_dataset/images
# Moved aa_129.png to synthetic_braille_dataset/images
# Moved aa_130.png to synthetic_braille_dataset/images
# Moved aa_131.png to synthetic_braille_dataset/images
# Moved aa_132.png to synthetic_braille_dataset/images
# Moved aa_133.png to synthetic_braille_dataset/images
# Moved aa_134.png to synthetic_braille_dataset/images
# Moved aa_135.png to synthetic_braille_dataset/images
# Moved aa_136.png to synthetic_braille_dataset/images
# Moved aa_137.png to synthetic_braille_dataset/images
# Moved aa_138.png to synthetic_braille_dataset/images
# Moved aa_139.png to synthetic_braille_dataset/images
# Moved aa_140.png to synthetic_braille_dataset/images
# Moved aa_141.png to synthetic_braille_dataset/images
# Moved aa_142.png to synthetic_braille_dataset/images
# Moved aa_143.png to synthetic_braille_dataset/images
# Moved aa_144.png to synthetic_braille_dataset/images
# Moved aa_145.png to synthetic_braille_dataset/images
# Moved aa_146.png to synthetic_braille_dataset/images
# Moved aa_147.png to synthetic_braille_dataset/images
# Moved aa_148.png to synthetic_braille_dataset/images
# Moved aa_149.png to synthetic_braille_dataset/images
# Moved aa_150.png to synthetic_braille_dataset/images
# Moved aa_151.png to synthetic_braille_dataset/images
# Moved aa_152.png to synthetic_braille_dataset/images
# Moved aa_153.png to synthetic_braille_dataset/images
# Moved aa_154.png to synthetic_braille_dataset/images
# Moved aa_155.png to synthetic_braille_dataset/images
# Moved aa_156.png to synthetic_braille_dataset/images
# Moved aa_157.png to synthetic_braille_dataset/images
# Moved aa_158.png to synthetic_braille_dataset/images
# Moved aa_159.png to synthetic_braille_dataset/images
# Moved aa_160.png to synthetic_braille_dataset/images
# Moved aa_161.png to synthetic_braille_dataset/images
# Moved aa_162.png to synthetic_braille_dataset/images
# Moved aa_163.png to synthetic_braille_dataset/images
# Moved aa_164.png to synthetic_braille_dataset/images
# Moved aa_165.png to synthetic_braille_dataset/images
# Moved aa_166.png to synthetic_braille_dataset/images
# Moved aa_167.png to synthetic_braille_dataset/images
# Moved aa_168.png to synthetic_braille_dataset/images
# Moved aa_169.png to synthetic_braille_dataset/images
# Moved aa_170.png to synthetic_braille_dataset/images
# Moved aa_171.png to synthetic_braille_dataset/images
# Moved aa_172.png to synthetic_braille_dataset/images
# Moved aa_173.png to synthetic_braille_dataset/images
# Moved aa_174.png to synthetic_braille_dataset/images
# Moved aa_175.png to synthetic_braille_dataset/images
# Moved aa_176.png to synthetic_braille_dataset/images
# Moved aa_177.png to synthetic_braille_dataset/images
# Moved aa_178.png to synthetic_braille_dataset/images
# Moved aa_179.png to synthetic_braille_dataset/images
# Moved aa_180.png to synthetic_braille_dataset/images
# Moved aa_181.png to synthetic_braille_dataset/images
# Moved aa_182.png to synthetic_braille_dataset/images
# Moved aa_183.png to synthetic_braille_dataset/images
# Moved aa_184.png to synthetic_braille_dataset/images
# Moved aa_185.png to synthetic_braille_dataset/images
# Moved aa_186.png to synthetic_braille_dataset/images
# Moved aa_187.png to synthetic_braille_dataset/images
# Moved aa_188.png to synthetic_braille_dataset/images
# Moved aa_189.png to synthetic_braille_dataset/images
# Moved aa_190.png to synthetic_braille_dataset/images
# Moved aa_191.png to synthetic_braille_dataset/images
# Moved aa_192.png to synthetic_braille_dataset/images
# Moved aa_193.png to synthetic_braille_dataset/images
# Moved aa_194.png to synthetic_braille_dataset/images
# Moved aa_195.png to synthetic_braille_dataset/images
# Moved aa_196.png to synthetic_braille_dataset/images
# Moved aa_197.png to synthetic_braille_dataset/images
# Moved aa_198.png to synthetic_braille_dataset/images
# Moved aa_199.png to synthetic_braille_dataset/images
# Moved aa_200.png to synthetic_braille_dataset/images
# Moved aa_201.png to synthetic_braille_dataset/images
# Moved aa_202.png to synthetic_braille_dataset/images
# Moved aa_203.png to synthetic_braille_dataset/images
# Moved aa_204.png to synthetic_braille_dataset/images
# Moved aa_205.png to synthetic_braille_dataset/images
# Moved aa_206.png to synthetic_braille_dataset/images
# Moved aa_207.png to synthetic_braille_dataset/images
# Moved aa_208.png to synthetic_braille_dataset/images
# Moved aa_209.png to synthetic_braille_dataset/images
# Moved aa_210.png to synthetic_braille_dataset/images
# Moved aa_211.png to synthetic_braille_dataset/images
# Moved aa_212.png to synthetic_braille_dataset/images
# Moved aa_213.png to synthetic_braille_dataset/images
# Moved aa_214.png to synthetic_braille_dataset/images
# Moved aa_215.png to synthetic_braille_dataset/images
# Moved aa_216.png to synthetic_braille_dataset/images
# Moved aa_217.png to synthetic_braille_dataset/images
# Moved aa_218.png to synthetic_braille_dataset/images
# Moved aa_219.png to synthetic_braille_dataset/images
# Moved aa_220.png to synthetic_braille_dataset/images
# Moved aa_221.png to synthetic_braille_dataset/images
# Moved aa_222.png to synthetic_braille_dataset/images
# Moved aa_223.png to synthetic_braille_dataset/images
# Moved aa_224.png to synthetic_braille_dataset/images
# Moved aa_225.png to synthetic_braille_dataset/images
# Moved aa_226.png to synthetic_braille_dataset/images
# Moved aa_227.png to synthetic_braille_dataset/images
# Moved aa_228.png to synthetic_braille_dataset/images
# Moved aa_229.png to synthetic_braille_dataset/images
# Moved aa_230.png to synthetic_braille_dataset/images
# Moved aa_231.png to synthetic_braille_dataset/images
# Moved aa_232.png to synthetic_braille_dataset/images
# Moved aa_233.png to synthetic_braille_dataset/images
# Moved aa_234.png to synthetic_braille_dataset/images
# Moved aa_235.png to synthetic_braille_dataset/images
# Moved aa_236.png to synthetic_braille_dataset/images
# Moved aa_237.png to synthetic_braille_dataset/images
# Moved aa_238.png to synthetic_braille_dataset/images
# Moved aa_239.png to synthetic_braille_dataset/images
# Moved aa_240.png to synthetic_braille_dataset/images
# Moved aa_241.png to synthetic_braille_dataset/images
# Moved aa_242.png to synthetic_braille_dataset/images
# Moved aa_243.png to synthetic_braille_dataset/images
# Moved aa_244.png to synthetic_braille_dataset/images
# Moved aa_245.png to synthetic_braille_dataset/images
# Moved aa_246.png to synthetic_braille_dataset/images
# Moved aa_247.png to synthetic_braille_dataset/images
# Moved aa_248.png to synthetic_braille_dataset/images
# Moved aa_249.png to synthetic_braille_dataset/images
# Moved i_000.png to synthetic_braille_dataset/images
# Moved i_001.png to synthetic_braille_dataset/images
# Moved i_002.png to synthetic_braille_dataset/images
# Moved i_003.png to synthetic_braille_dataset/images
# Moved i_004.png to synthetic_braille_dataset/images
# Moved i_005.png to synthetic_braille_dataset/images
# Moved i_006.png to synthetic_braille_dataset/images
# Moved i_007.png to synthetic_braille_dataset/images
# Moved i_008.png to synthetic_braille_dataset/images
# Moved i_009.png to synthetic_braille_dataset/images
# Moved i_010.png to synthetic_braille_dataset/images
# Moved i_011.png to synthetic_braille_dataset/images
# Moved i_012.png to synthetic_braille_dataset/images
# Moved i_013.png to synthetic_braille_dataset/images
# Moved i_014.png to synthetic_braille_dataset/images
# Moved i_015.png to synthetic_braille_dataset/images
# Moved i_016.png to synthetic_braille_dataset/images
# Moved i_017.png to synthetic_braille_dataset/images
# Moved i_018.png to synthetic_braille_dataset/images
# Moved i_019.png to synthetic_braille_dataset/images
# Moved i_020.png to synthetic_braille_dataset/images
# Moved i_021.png to synthetic_braille_dataset/images
# Moved i_022.png to synthetic_braille_dataset/images
# Moved i_023.png to synthetic_braille_dataset/images
# Moved i_024.png to synthetic_braille_dataset/images
# Moved i_025.png to synthetic_braille_dataset/images
# Moved i_026.png to synthetic_braille_dataset/images
# Moved i_027.png to synthetic_braille_dataset/images
# Moved i_028.png to synthetic_braille_dataset/images
# Moved i_029.png to synthetic_braille_dataset/images
# Moved i_030.png to synthetic_braille_dataset/images
# Moved i_031.png to synthetic_braille_dataset/images
# Moved i_032.png to synthetic_braille_dataset/images
# Moved i_033.png to synthetic_braille_dataset/images
# Moved i_034.png to synthetic_braille_dataset/images
# Moved i_035.png to synthetic_braille_dataset/images
# Moved i_036.png to synthetic_braille_dataset/images
# Moved i_037.png to synthetic_braille_dataset/images
# Moved i_038.png to synthetic_braille_dataset/images
# Moved i_039.png to synthetic_braille_dataset/images
# Moved i_040.png to synthetic_braille_dataset/images
# Moved i_041.png to synthetic_braille_dataset/images
# Moved i_042.png to synthetic_braille_dataset/images
# Moved i_043.png to synthetic_braille_dataset/images
# Moved i_044.png to synthetic_braille_dataset/images
# Moved i_045.png to synthetic_braille_dataset/images
# Moved i_046.png to synthetic_braille_dataset/images
# Moved i_047.png to synthetic_braille_dataset/images
# Moved i_048.png to synthetic_braille_dataset/images
# Moved i_049.png to synthetic_braille_dataset/images
# Moved i_050.png to synthetic_braille_dataset/images
# Moved i_051.png to synthetic_braille_dataset/images
# Moved i_052.png to synthetic_braille_dataset/images
# Moved i_053.png to synthetic_braille_dataset/images
# Moved i_054.png to synthetic_braille_dataset/images
# Moved i_055.png to synthetic_braille_dataset/images
# Moved i_056.png to synthetic_braille_dataset/images
# Moved i_057.png to synthetic_braille_dataset/images
# Moved i_058.png to synthetic_braille_dataset/images
# Moved i_059.png to synthetic_braille_dataset/images
# Moved i_060.png to synthetic_braille_dataset/images
# Moved i_061.png to synthetic_braille_dataset/images
# Moved i_062.png to synthetic_braille_dataset/images
# Moved i_063.png to synthetic_braille_dataset/images
# Moved i_064.png to synthetic_braille_dataset/images
# Moved i_065.png to synthetic_braille_dataset/images
# Moved i_066.png to synthetic_braille_dataset/images
# Moved i_067.png to synthetic_braille_dataset/images
# Moved i_068.png to synthetic_braille_dataset/images
# Moved i_069.png to synthetic_braille_dataset/images
# Moved i_070.png to synthetic_braille_dataset/images
# Moved i_071.png to synthetic_braille_dataset/images
# Moved i_072.png to synthetic_braille_dataset/images
# Moved i_073.png to synthetic_braille_dataset/images
# Moved i_074.png to synthetic_braille_dataset/images
# Moved i_075.png to synthetic_braille_dataset/images
# Moved i_076.png to synthetic_braille_dataset/images
# Moved i_077.png to synthetic_braille_dataset/images
# Moved i_078.png to synthetic_braille_dataset/images
# Moved i_079.png to synthetic_braille_dataset/images
# Moved i_080.png to synthetic_braille_dataset/images
# Moved i_081.png to synthetic_braille_dataset/images
# Moved i_082.png to synthetic_braille_dataset/images
# Moved i_083.png to synthetic_braille_dataset/images
# Moved i_084.png to synthetic_braille_dataset/images
# Moved i_085.png to synthetic_braille_dataset/images
# Moved i_086.png to synthetic_braille_dataset/images
# Moved i_087.png to synthetic_braille_dataset/images
# Moved i_088.png to synthetic_braille_dataset/images
# Moved i_089.png to synthetic_braille_dataset/images
# Moved i_090.png to synthetic_braille_dataset/images
# Moved i_091.png to synthetic_braille_dataset/images
# Moved i_092.png to synthetic_braille_dataset/images
# Moved i_093.png to synthetic_braille_dataset/images
# Moved i_094.png to synthetic_braille_dataset/images
# Moved i_095.png to synthetic_braille_dataset/images
# Moved i_096.png to synthetic_braille_dataset/images
# Moved i_097.png to synthetic_braille_dataset/images
# Moved i_098.png to synthetic_braille_dataset/images
# Moved i_099.png to synthetic_braille_dataset/images
# Moved i_100.png to synthetic_braille_dataset/images
# Moved i_101.png to synthetic_braille_dataset/images
# Moved i_102.png to synthetic_braille_dataset/images
# Moved i_103.png to synthetic_braille_dataset/images
# Moved i_104.png to synthetic_braille_dataset/images
# Moved i_105.png to synthetic_braille_dataset/images
# Moved i_106.png to synthetic_braille_dataset/images
# Moved i_107.png to synthetic_braille_dataset/images
# Moved i_108.png to synthetic_braille_dataset/images
# Moved i_109.png to synthetic_braille_dataset/images
# Moved i_110.png to synthetic_braille_dataset/images
# Moved i_111.png to synthetic_braille_dataset/images
# Moved i_112.png to synthetic_braille_dataset/images
# Moved i_113.png to synthetic_braille_dataset/images
# Moved i_114.png to synthetic_braille_dataset/images
# Moved i_115.png to synthetic_braille_dataset/images
# Moved i_116.png to synthetic_braille_dataset/images
# Moved i_117.png to synthetic_braille_dataset/images
# Moved i_118.png to synthetic_braille_dataset/images
# Moved i_119.png to synthetic_braille_dataset/images
# Moved i_120.png to synthetic_braille_dataset/images
# Moved i_121.png to synthetic_braille_dataset/images
# Moved i_122.png to synthetic_braille_dataset/images
# Moved i_123.png to synthetic_braille_dataset/images
# Moved i_124.png to synthetic_braille_dataset/images
# Moved i_125.png to synthetic_braille_dataset/images
# Moved i_126.png to synthetic_braille_dataset/images
# Moved i_127.png to synthetic_braille_dataset/images
# Moved i_128.png to synthetic_braille_dataset/images
# Moved i_129.png to synthetic_braille_dataset/images
# Moved i_130.png to synthetic_braille_dataset/images
# Moved i_131.png to synthetic_braille_dataset/images
# Moved i_132.png to synthetic_braille_dataset/images
# Moved i_133.png to synthetic_braille_dataset/images
# Moved i_134.png to synthetic_braille_dataset/images
# Moved i_135.png to synthetic_braille_dataset/images
# Moved i_136.png to synthetic_braille_dataset/images
# Moved i_137.png to synthetic_braille_dataset/images
# Moved i_138.png to synthetic_braille_dataset/images
# Moved i_139.png to synthetic_braille_dataset/images
# Moved i_140.png to synthetic_braille_dataset/images
# Moved i_141.png to synthetic_braille_dataset/images
# Moved i_142.png to synthetic_braille_dataset/images
# Moved i_143.png to synthetic_braille_dataset/images
# Moved i_144.png to synthetic_braille_dataset/images
# Moved i_145.png to synthetic_braille_dataset/images
# Moved i_146.png to synthetic_braille_dataset/images
# Moved i_147.png to synthetic_braille_dataset/images
# Moved i_148.png to synthetic_braille_dataset/images
# Moved i_149.png to synthetic_braille_dataset/images
# Moved i_150.png to synthetic_braille_dataset/images
# Moved i_151.png to synthetic_braille_dataset/images
# Moved i_152.png to synthetic_braille_dataset/images
# Moved i_153.png to synthetic_braille_dataset/images
# Moved i_154.png to synthetic_braille_dataset/images
# Moved i_155.png to synthetic_braille_dataset/images
# Moved i_156.png to synthetic_braille_dataset/images
# Moved i_157.png to synthetic_braille_dataset/images
# Moved i_158.png to synthetic_braille_dataset/images
# Moved i_159.png to synthetic_braille_dataset/images
# Moved i_160.png to synthetic_braille_dataset/images
# Moved i_161.png to synthetic_braille_dataset/images
# Moved i_162.png to synthetic_braille_dataset/images
# Moved i_163.png to synthetic_braille_dataset/images
# Moved i_164.png to synthetic_braille_dataset/images
# Moved i_165.png to synthetic_braille_dataset/images
# Moved i_166.png to synthetic_braille_dataset/images
# Moved i_167.png to synthetic_braille_dataset/images
# Moved i_168.png to synthetic_braille_dataset/images
# Moved i_169.png to synthetic_braille_dataset/images
# Moved i_170.png to synthetic_braille_dataset/images
# Moved i_171.png to synthetic_braille_dataset/images
# Moved i_172.png to synthetic_braille_dataset/images
# Moved i_173.png to synthetic_braille_dataset/images
# Moved i_174.png to synthetic_braille_dataset/images
# Moved i_175.png to synthetic_braille_dataset/images
# Moved i_176.png to synthetic_braille_dataset/images
# Moved i_177.png to synthetic_braille_dataset/images
# Moved i_178.png to synthetic_braille_dataset/images
# Moved i_179.png to synthetic_braille_dataset/images
# Moved i_180.png to synthetic_braille_dataset/images
# Moved i_181.png to synthetic_braille_dataset/images
# Moved i_182.png to synthetic_braille_dataset/images
# Moved i_183.png to synthetic_braille_dataset/images
# Moved i_184.png to synthetic_braille_dataset/images
# Moved i_185.png to synthetic_braille_dataset/images
# Moved i_186.png to synthetic_braille_dataset/images
# Moved i_187.png to synthetic_braille_dataset/images
# Moved i_188.png to synthetic_braille_dataset/images
# Moved i_189.png to synthetic_braille_dataset/images
# Moved i_190.png to synthetic_braille_dataset/images
# Moved i_191.png to synthetic_braille_dataset/images
# Moved i_192.png to synthetic_braille_dataset/images
# Moved i_193.png to synthetic_braille_dataset/images
# Moved i_194.png to synthetic_braille_dataset/images
# Moved i_195.png to synthetic_braille_dataset/images
# Moved i_196.png to synthetic_braille_dataset/images
# Moved i_197.png to synthetic_braille_dataset/images
# Moved i_198.png to synthetic_braille_dataset/images
# Moved i_199.png to synthetic_braille_dataset/images
# Moved i_200.png to synthetic_braille_dataset/images
# Moved i_201.png to synthetic_braille_dataset/images
# Moved i_202.png to synthetic_braille_dataset/images
# Moved i_203.png to synthetic_braille_dataset/images
# Moved i_204.png to synthetic_braille_dataset/images
# Moved i_205.png to synthetic_braille_dataset/images
# Moved i_206.png to synthetic_braille_dataset/images
# Moved i_207.png to synthetic_braille_dataset/images
# Moved i_208.png to synthetic_braille_dataset/images
# Moved i_209.png to synthetic_braille_dataset/images
# Moved i_210.png to synthetic_braille_dataset/images
# Moved i_211.png to synthetic_braille_dataset/images
# Moved i_212.png to synthetic_braille_dataset/images
# Moved i_213.png to synthetic_braille_dataset/images
# Moved i_214.png to synthetic_braille_dataset/images
# Moved i_215.png to synthetic_braille_dataset/images
# Moved i_216.png to synthetic_braille_dataset/images
# Moved i_217.png to synthetic_braille_dataset/images
# Moved i_218.png to synthetic_braille_dataset/images
# Moved i_219.png to synthetic_braille_dataset/images
# Moved i_220.png to synthetic_braille_dataset/images
# Moved i_221.png to synthetic_braille_dataset/images
# Moved i_222.png to synthetic_braille_dataset/images
# Moved i_223.png to synthetic_braille_dataset/images
# Moved i_224.png to synthetic_braille_dataset/images
# Moved i_225.png to synthetic_braille_dataset/images
# Moved i_226.png to synthetic_braille_dataset/images
# Moved i_227.png to synthetic_braille_dataset/images
# Moved i_228.png to synthetic_braille_dataset/images
# Moved i_229.png to synthetic_braille_dataset/images
# Moved i_230.png to synthetic_braille_dataset/images
# Moved i_231.png to synthetic_braille_dataset/images
# Moved i_232.png to synthetic_braille_dataset/images
# Moved i_233.png to synthetic_braille_dataset/images
# Moved i_234.png to synthetic_braille_dataset/images
# Moved i_235.png to synthetic_braille_dataset/images
# Moved i_236.png to synthetic_braille_dataset/images
# Moved i_237.png to synthetic_braille_dataset/images
# Moved i_238.png to synthetic_braille_dataset/images
# Moved i_239.png to synthetic_braille_dataset/images
# Moved i_240.png to synthetic_braille_dataset/images
# Moved i_241.png to synthetic_braille_dataset/images
# Moved i_242.png to synthetic_braille_dataset/images
# Moved i_243.png to synthetic_braille_dataset/images
# Moved i_244.png to synthetic_braille_dataset/images
# Moved i_245.png to synthetic_braille_dataset/images
# Moved i_246.png to synthetic_braille_dataset/images
# Moved i_247.png to synthetic_braille_dataset/images
# Moved i_248.png to synthetic_braille_dataset/images
# Moved i_249.png to synthetic_braille_dataset/images
# Moved ii_000.png to synthetic_braille_dataset/images
# Moved ii_001.png to synthetic_braille_dataset/images
# Moved ii_002.png to synthetic_braille_dataset/images
# Moved ii_003.png to synthetic_braille_dataset/images
# Moved ii_004.png to synthetic_braille_dataset/images
# Moved ii_005.png to synthetic_braille_dataset/images
# Moved ii_006.png to synthetic_braille_dataset/images
# Moved ii_007.png to synthetic_braille_dataset/images
# Moved ii_008.png to synthetic_braille_dataset/images
# Moved ii_009.png to synthetic_braille_dataset/images
# Moved ii_010.png to synthetic_braille_dataset/images
# Moved ii_011.png to synthetic_braille_dataset/images
# Moved ii_012.png to synthetic_braille_dataset/images
# Moved ii_013.png to synthetic_braille_dataset/images
# Moved ii_014.png to synthetic_braille_dataset/images
# Moved ii_015.png to synthetic_braille_dataset/images
# Moved ii_016.png to synthetic_braille_dataset/images
# Moved ii_017.png to synthetic_braille_dataset/images
# Moved ii_018.png to synthetic_braille_dataset/images
# Moved ii_019.png to synthetic_braille_dataset/images
# Moved ii_020.png to synthetic_braille_dataset/images
# Moved ii_021.png to synthetic_braille_dataset/images
# Moved ii_022.png to synthetic_braille_dataset/images
# Moved ii_023.png to synthetic_braille_dataset/images
# Moved ii_024.png to synthetic_braille_dataset/images
# Moved ii_025.png to synthetic_braille_dataset/images
# Moved ii_026.png to synthetic_braille_dataset/images
# Moved ii_027.png to synthetic_braille_dataset/images
# Moved ii_028.png to synthetic_braille_dataset/images
# Moved ii_029.png to synthetic_braille_dataset/images
# Moved ii_030.png to synthetic_braille_dataset/images
# Moved ii_031.png to synthetic_braille_dataset/images
# Moved ii_032.png to synthetic_braille_dataset/images
# Moved ii_033.png to synthetic_braille_dataset/images
# Moved ii_034.png to synthetic_braille_dataset/images
# Moved ii_035.png to synthetic_braille_dataset/images
# Moved ii_036.png to synthetic_braille_dataset/images
# Moved ii_037.png to synthetic_braille_dataset/images
# Moved ii_038.png to synthetic_braille_dataset/images
# Moved ii_039.png to synthetic_braille_dataset/images
# Moved ii_040.png to synthetic_braille_dataset/images
# Moved ii_041.png to synthetic_braille_dataset/images
# Moved ii_042.png to synthetic_braille_dataset/images
# Moved ii_043.png to synthetic_braille_dataset/images
# Moved ii_044.png to synthetic_braille_dataset/images
# Moved ii_045.png to synthetic_braille_dataset/images
# Moved ii_046.png to synthetic_braille_dataset/images
# Moved ii_047.png to synthetic_braille_dataset/images
# Moved ii_048.png to synthetic_braille_dataset/images
# Moved ii_049.png to synthetic_braille_dataset/images
# Moved ii_050.png to synthetic_braille_dataset/images
# Moved ii_051.png to synthetic_braille_dataset/images
# Moved ii_052.png to synthetic_braille_dataset/images
# Moved ii_053.png to synthetic_braille_dataset/images
# Moved ii_054.png to synthetic_braille_dataset/images
# Moved ii_055.png to synthetic_braille_dataset/images
# Moved ii_056.png to synthetic_braille_dataset/images
# Moved ii_057.png to synthetic_braille_dataset/images
# Moved ii_058.png to synthetic_braille_dataset/images
# Moved ii_059.png to synthetic_braille_dataset/images
# Moved ii_060.png to synthetic_braille_dataset/images
# Moved ii_061.png to synthetic_braille_dataset/images
# Moved ii_062.png to synthetic_braille_dataset/images
# Moved ii_063.png to synthetic_braille_dataset/images
# Moved ii_064.png to synthetic_braille_dataset/images
# Moved ii_065.png to synthetic_braille_dataset/images
# Moved ii_066.png to synthetic_braille_dataset/images
# Moved ii_067.png to synthetic_braille_dataset/images
# Moved ii_068.png to synthetic_braille_dataset/images
# Moved ii_069.png to synthetic_braille_dataset/images
# Moved ii_070.png to synthetic_braille_dataset/images
# Moved ii_071.png to synthetic_braille_dataset/images
# Moved ii_072.png to synthetic_braille_dataset/images
# Moved ii_073.png to synthetic_braille_dataset/images
# Moved ii_074.png to synthetic_braille_dataset/images
# Moved ii_075.png to synthetic_braille_dataset/images
# Moved ii_076.png to synthetic_braille_dataset/images
# Moved ii_077.png to synthetic_braille_dataset/images
# Moved ii_078.png to synthetic_braille_dataset/images
# Moved ii_079.png to synthetic_braille_dataset/images
# Moved ii_080.png to synthetic_braille_dataset/images
# Moved ii_081.png to synthetic_braille_dataset/images
# Moved ii_082.png to synthetic_braille_dataset/images
# Moved ii_083.png to synthetic_braille_dataset/images
# Moved ii_084.png to synthetic_braille_dataset/images
# Moved ii_085.png to synthetic_braille_dataset/images
# Moved ii_086.png to synthetic_braille_dataset/images
# Moved ii_087.png to synthetic_braille_dataset/images
# Moved ii_088.png to synthetic_braille_dataset/images
# Moved ii_089.png to synthetic_braille_dataset/images
# Moved ii_090.png to synthetic_braille_dataset/images
# Moved ii_091.png to synthetic_braille_dataset/images
# Moved ii_092.png to synthetic_braille_dataset/images
# Moved ii_093.png to synthetic_braille_dataset/images
# Moved ii_094.png to synthetic_braille_dataset/images
# Moved ii_095.png to synthetic_braille_dataset/images
# Moved ii_096.png to synthetic_braille_dataset/images
# Moved ii_097.png to synthetic_braille_dataset/images
# Moved ii_098.png to synthetic_braille_dataset/images
# Moved ii_099.png to synthetic_braille_dataset/images
# Moved ii_100.png to synthetic_braille_dataset/images
# Moved ii_101.png to synthetic_braille_dataset/images
# Moved ii_102.png to synthetic_braille_dataset/images
# Moved ii_103.png to synthetic_braille_dataset/images
# Moved ii_104.png to synthetic_braille_dataset/images
# Moved ii_105.png to synthetic_braille_dataset/images
# Moved ii_106.png to synthetic_braille_dataset/images
# Moved ii_107.png to synthetic_braille_dataset/images
# Moved ii_108.png to synthetic_braille_dataset/images
# Moved ii_109.png to synthetic_braille_dataset/images
# Moved ii_110.png to synthetic_braille_dataset/images
# Moved ii_111.png to synthetic_braille_dataset/images
# Moved ii_112.png to synthetic_braille_dataset/images
# Moved ii_113.png to synthetic_braille_dataset/images
# Moved ii_114.png to synthetic_braille_dataset/images
# Moved ii_115.png to synthetic_braille_dataset/images
# Moved ii_116.png to synthetic_braille_dataset/images
# Moved ii_117.png to synthetic_braille_dataset/images
# Moved ii_118.png to synthetic_braille_dataset/images
# Moved ii_119.png to synthetic_braille_dataset/images
# Moved ii_120.png to synthetic_braille_dataset/images
# Moved ii_121.png to synthetic_braille_dataset/images
# Moved ii_122.png to synthetic_braille_dataset/images
# Moved ii_123.png to synthetic_braille_dataset/images
# Moved ii_124.png to synthetic_braille_dataset/images
# Moved ii_125.png to synthetic_braille_dataset/images
# Moved ii_126.png to synthetic_braille_dataset/images
# Moved ii_127.png to synthetic_braille_dataset/images
# Moved ii_128.png to synthetic_braille_dataset/images
# Moved ii_129.png to synthetic_braille_dataset/images
# Moved ii_130.png to synthetic_braille_dataset/images
# Moved ii_131.png to synthetic_braille_dataset/images
# Moved ii_132.png to synthetic_braille_dataset/images
# Moved ii_133.png to synthetic_braille_dataset/images
# Moved ii_134.png to synthetic_braille_dataset/images
# Moved ii_135.png to synthetic_braille_dataset/images
# Moved ii_136.png to synthetic_braille_dataset/images
# Moved ii_137.png to synthetic_braille_dataset/images
# Moved ii_138.png to synthetic_braille_dataset/images
# Moved ii_139.png to synthetic_braille_dataset/images
# Moved ii_140.png to synthetic_braille_dataset/images
# Moved ii_141.png to synthetic_braille_dataset/images
# Moved ii_142.png to synthetic_braille_dataset/images
# Moved ii_143.png to synthetic_braille_dataset/images
# Moved ii_144.png to synthetic_braille_dataset/images
# Moved ii_145.png to synthetic_braille_dataset/images
# Moved ii_146.png to synthetic_braille_dataset/images
# Moved ii_147.png to synthetic_braille_dataset/images
# Moved ii_148.png to synthetic_braille_dataset/images
# Moved ii_149.png to synthetic_braille_dataset/images
# Moved ii_150.png to synthetic_braille_dataset/images
# Moved ii_151.png to synthetic_braille_dataset/images
# Moved ii_152.png to synthetic_braille_dataset/images
# Moved ii_153.png to synthetic_braille_dataset/images
# Moved ii_154.png to synthetic_braille_dataset/images
# Moved ii_155.png to synthetic_braille_dataset/images
# Moved ii_156.png to synthetic_braille_dataset/images
# Moved ii_157.png to synthetic_braille_dataset/images
# Moved ii_158.png to synthetic_braille_dataset/images
# Moved ii_159.png to synthetic_braille_dataset/images
# Moved ii_160.png to synthetic_braille_dataset/images
# Moved ii_161.png to synthetic_braille_dataset/images
# Moved ii_162.png to synthetic_braille_dataset/images
# Moved ii_163.png to synthetic_braille_dataset/images
# Moved ii_164.png to synthetic_braille_dataset/images
# ...
# Moved ksha_205.png to synthetic_braille_dataset/images
# Moved ksha_206.png to synthetic_braille_dataset/images
# Moved ksha_207.png to synthetic_braille_dataset/images
# Moved ksha_208.png to synthetic_braille_dataset/images
# Moved ksha_209.png to synthetic_braille_dataset/images
# Moved ksha_210.png to synthetic_braille_dataset/images
# Moved ksha_211.png to synthetic_braille_dataset/images
# Moved ksha_212.png to synthetic_braille_dataset/images
# Moved ksha_213.png to synthetic_braille_dataset/images
# Moved ksha_214.png to synthetic_braille_dataset/images
# Moved ksha_215.png to synthetic_braille_dataset/images
# Moved ksha_216.png to synthetic_braille_dataset/images
# Moved ksha_217.png to synthetic_braille_dataset/images
# Moved ksha_218.png to synthetic_braille_dataset/images
# Moved ksha_219.png to synthetic_braille_dataset/images
# Moved ksha_220.png to synthetic_braille_dataset/images
# Moved ksha_221.png to synthetic_braille_dataset/images
# Moved ksha_222.png to synthetic_braille_dataset/images
# Moved ksha_223.png to synthetic_braille_dataset/images
# Moved ksha_224.png to synthetic_braille_dataset/images
# Moved ksha_225.png to synthetic_braille_dataset/images
# Moved ksha_226.png to synthetic_braille_dataset/images
# Moved ksha_227.png to synthetic_braille_dataset/images
# Moved ksha_228.png to synthetic_braille_dataset/images
# Moved ksha_229.png to synthetic_braille_dataset/images
# Moved ksha_230.png to synthetic_braille_dataset/images
# Moved ksha_231.png to synthetic_braille_dataset/images
# Moved ksha_232.png to synthetic_braille_dataset/images
# Moved ksha_233.png to synthetic_braille_dataset/images
# Moved ksha_234.png to synthetic_braille_dataset/images
# Moved ksha_235.png to synthetic_braille_dataset/images
# Moved ksha_236.png to synthetic_braille_dataset/images
# Moved ksha_237.png to synthetic_braille_dataset/images
# Moved ksha_238.png to synthetic_braille_dataset/images
# Moved ksha_239.png to synthetic_braille_dataset/images
# Moved ksha_240.png to synthetic_braille_dataset/images
# Moved ksha_241.png to synthetic_braille_dataset/images
# Moved ksha_242.png to synthetic_braille_dataset/images
# Moved ksha_243.png to synthetic_braille_dataset/images
# Moved ksha_244.png to synthetic_braille_dataset/images
# Moved ksha_245.png to synthetic_braille_dataset/images
# Moved ksha_246.png to synthetic_braille_dataset/images
# Moved ksha_247.png to synthetic_braille_dataset/images
# Moved ksha_248.png to synthetic_braille_dataset/images
# Moved ksha_249.png to synthetic_braille_dataset/images
# Moved gya_000.png to synthetic_braille_dataset/images
# Moved gya_001.png to synthetic_braille_dataset/images
# Moved gya_002.png to synthetic_braille_dataset/images
# Moved gya_003.png to synthetic_braille_dataset/images
# Moved gya_004.png to synthetic_braille_dataset/images
# Moved gya_005.png to synthetic_braille_dataset/images
# Moved gya_006.png to synthetic_braille_dataset/images
# Moved gya_007.png to synthetic_braille_dataset/images
# Moved gya_008.png to synthetic_braille_dataset/images
# Moved gya_009.png to synthetic_braille_dataset/images
# Moved gya_010.png to synthetic_braille_dataset/images
# Moved gya_011.png to synthetic_braille_dataset/images
# Moved gya_012.png to synthetic_braille_dataset/images
# Moved gya_013.png to synthetic_braille_dataset/images
# Moved gya_014.png to synthetic_braille_dataset/images
# Moved gya_015.png to synthetic_braille_dataset/images
# Moved gya_016.png to synthetic_braille_dataset/images
# Moved gya_017.png to synthetic_braille_dataset/images
# Moved gya_018.png to synthetic_braille_dataset/images
# Moved gya_019.png to synthetic_braille_dataset/images
# Moved gya_020.png to synthetic_braille_dataset/images
# Moved gya_021.png to synthetic_braille_dataset/images
# Moved gya_022.png to synthetic_braille_dataset/images
# Moved gya_023.png to synthetic_braille_dataset/images
# Moved gya_024.png to synthetic_braille_dataset/images
# Moved gya_025.png to synthetic_braille_dataset/images
# Moved gya_026.png to synthetic_braille_dataset/images
# Moved gya_027.png to synthetic_braille_dataset/images
# Moved gya_028.png to synthetic_braille_dataset/images
# Moved gya_029.png to synthetic_braille_dataset/images
# Moved gya_030.png to synthetic_braille_dataset/images
# Moved gya_031.png to synthetic_braille_dataset/images
# Moved gya_032.png to synthetic_braille_dataset/images
# Moved gya_033.png to synthetic_braille_dataset/images
# Moved gya_034.png to synthetic_braille_dataset/images
# Moved gya_035.png to synthetic_braille_dataset/images
# Moved gya_036.png to synthetic_braille_dataset/images
# Moved gya_037.png to synthetic_braille_dataset/images
# Moved gya_038.png to synthetic_braille_dataset/images
# Moved gya_039.png to synthetic_braille_dataset/images
# Moved gya_040.png to synthetic_braille_dataset/images
# Moved gya_041.png to synthetic_braille_dataset/images
# Moved gya_042.png to synthetic_braille_dataset/images
# Moved gya_043.png to synthetic_braille_dataset/images
# Moved gya_044.png to synthetic_braille_dataset/images
# Moved gya_045.png to synthetic_braille_dataset/images
# Moved gya_046.png to synthetic_braille_dataset/images
# Moved gya_047.png to synthetic_braille_dataset/images
# Moved gya_048.png to synthetic_braille_dataset/images
# Moved gya_049.png to synthetic_braille_dataset/images
# Moved gya_050.png to synthetic_braille_dataset/images
# Moved gya_051.png to synthetic_braille_dataset/images
# Moved gya_052.png to synthetic_braille_dataset/images
# Moved gya_053.png to synthetic_braille_dataset/images
# Moved gya_054.png to synthetic_braille_dataset/images
# Moved gya_055.png to synthetic_braille_dataset/images
# Moved gya_056.png to synthetic_braille_dataset/images
# Moved gya_057.png to synthetic_braille_dataset/images
# Moved gya_058.png to synthetic_braille_dataset/images
# Moved gya_059.png to synthetic_braille_dataset/images
# Moved gya_060.png to synthetic_braille_dataset/images
# Moved gya_061.png to synthetic_braille_dataset/images
# Moved gya_062.png to synthetic_braille_dataset/images
# Moved gya_063.png to synthetic_braille_dataset/images
# Moved gya_064.png to synthetic_braille_dataset/images
# Moved gya_065.png to synthetic_braille_dataset/images
# Moved gya_066.png to synthetic_braille_dataset/images
# Moved gya_067.png to synthetic_braille_dataset/images
# Moved gya_068.png to synthetic_braille_dataset/images
# Moved gya_069.png to synthetic_braille_dataset/images
# Moved gya_070.png to synthetic_braille_dataset/images
# Moved gya_071.png to synthetic_braille_dataset/images
# Moved gya_072.png to synthetic_braille_dataset/images
# Moved gya_073.png to synthetic_braille_dataset/images
# Moved gya_074.png to synthetic_braille_dataset/images
# Moved gya_075.png to synthetic_braille_dataset/images
# Moved gya_076.png to synthetic_braille_dataset/images
# Moved gya_077.png to synthetic_braille_dataset/images
# Moved gya_078.png to synthetic_braille_dataset/images
# Moved gya_079.png to synthetic_braille_dataset/images
# Moved gya_080.png to synthetic_braille_dataset/images
# Moved gya_081.png to synthetic_braille_dataset/images
# Moved gya_082.png to synthetic_braille_dataset/images
# Moved gya_083.png to synthetic_braille_dataset/images
# Moved gya_084.png to synthetic_braille_dataset/images
# Moved gya_085.png to synthetic_braille_dataset/images
# Moved gya_086.png to synthetic_braille_dataset/images
# Moved gya_087.png to synthetic_braille_dataset/images
# Moved gya_088.png to synthetic_braille_dataset/images
# Moved gya_089.png to synthetic_braille_dataset/images
# Moved gya_090.png to synthetic_braille_dataset/images
# Moved gya_091.png to synthetic_braille_dataset/images
# Moved gya_092.png to synthetic_braille_dataset/images
# Moved gya_093.png to synthetic_braille_dataset/images
# Moved gya_094.png to synthetic_braille_dataset/images
# Moved gya_095.png to synthetic_braille_dataset/images
# Moved gya_096.png to synthetic_braille_dataset/images
# Moved gya_097.png to synthetic_braille_dataset/images
# Moved gya_098.png to synthetic_braille_dataset/images
# Moved gya_099.png to synthetic_braille_dataset/images
# Moved gya_100.png to synthetic_braille_dataset/images
# Moved gya_101.png to synthetic_braille_dataset/images
# Moved gya_102.png to synthetic_braille_dataset/images
# Moved gya_103.png to synthetic_braille_dataset/images
# Moved gya_104.png to synthetic_braille_dataset/images
# Moved gya_105.png to synthetic_braille_dataset/images
# Moved gya_106.png to synthetic_braille_dataset/images
# Moved gya_107.png to synthetic_braille_dataset/images
# Moved gya_108.png to synthetic_braille_dataset/images
# Moved gya_109.png to synthetic_braille_dataset/images
# Moved gya_110.png to synthetic_braille_dataset/images
# Moved gya_111.png to synthetic_braille_dataset/images
# Moved gya_112.png to synthetic_braille_dataset/images
# Moved gya_113.png to synthetic_braille_dataset/images
# Moved gya_114.png to synthetic_braille_dataset/images
# Moved gya_115.png to synthetic_braille_dataset/images
# Moved gya_116.png to synthetic_braille_dataset/images
# Moved gya_117.png to synthetic_braille_dataset/images
# Moved gya_118.png to synthetic_braille_dataset/images
# Moved gya_119.png to synthetic_braille_dataset/images
# Moved gya_120.png to synthetic_braille_dataset/images
# Moved gya_121.png to synthetic_braille_dataset/images
# Moved gya_122.png to synthetic_braille_dataset/images
# Moved gya_123.png to synthetic_braille_dataset/images
# Moved gya_124.png to synthetic_braille_dataset/images
# Moved gya_125.png to synthetic_braille_dataset/images
# Moved gya_126.png to synthetic_braille_dataset/images
# Moved gya_127.png to synthetic_braille_dataset/images
# Moved gya_128.png to synthetic_braille_dataset/images
# Moved gya_129.png to synthetic_braille_dataset/images
# Moved gya_130.png to synthetic_braille_dataset/images
# Moved gya_131.png to synthetic_braille_dataset/images
# Moved gya_132.png to synthetic_braille_dataset/images
# Moved gya_133.png to synthetic_braille_dataset/images
# Moved gya_134.png to synthetic_braille_dataset/images
# Moved gya_135.png to synthetic_braille_dataset/images
# Moved gya_136.png to synthetic_braille_dataset/images
# Moved gya_137.png to synthetic_braille_dataset/images
# Moved gya_138.png to synthetic_braille_dataset/images
# Moved gya_139.png to synthetic_braille_dataset/images
# Moved gya_140.png to synthetic_braille_dataset/images
# Moved gya_141.png to synthetic_braille_dataset/images
# Moved gya_142.png to synthetic_braille_dataset/images
# Moved gya_143.png to synthetic_braille_dataset/images
# Moved gya_144.png to synthetic_braille_dataset/images
# Moved gya_145.png to synthetic_braille_dataset/images
# Moved gya_146.png to synthetic_braille_dataset/images
# Moved gya_147.png to synthetic_braille_dataset/images
# Moved gya_148.png to synthetic_braille_dataset/images
# Moved gya_149.png to synthetic_braille_dataset/images
# Moved gya_150.png to synthetic_braille_dataset/images
# Moved gya_151.png to synthetic_braille_dataset/images
# Moved gya_152.png to synthetic_braille_dataset/images
# Moved gya_153.png to synthetic_braille_dataset/images
# Moved gya_154.png to synthetic_braille_dataset/images
# Moved gya_155.png to synthetic_braille_dataset/images
# Moved gya_156.png to synthetic_braille_dataset/images
# Moved gya_157.png to synthetic_braille_dataset/images
# Moved gya_158.png to synthetic_braille_dataset/images
# Moved gya_159.png to synthetic_braille_dataset/images
# Moved gya_160.png to synthetic_braille_dataset/images
# Moved gya_161.png to synthetic_braille_dataset/images
# Moved gya_162.png to synthetic_braille_dataset/images
# Moved gya_163.png to synthetic_braille_dataset/images
# Moved gya_164.png to synthetic_braille_dataset/images
# Moved gya_165.png to synthetic_braille_dataset/images
# Moved gya_166.png to synthetic_braille_dataset/images
# Moved gya_167.png to synthetic_braille_dataset/images
# Moved gya_168.png to synthetic_braille_dataset/images
# Moved gya_169.png to synthetic_braille_dataset/images
# Moved gya_170.png to synthetic_braille_dataset/images
# Moved gya_171.png to synthetic_braille_dataset/images
# Moved gya_172.png to synthetic_braille_dataset/images
# Moved gya_173.png to synthetic_braille_dataset/images
# Moved gya_174.png to synthetic_braille_dataset/images
# Moved gya_175.png to synthetic_braille_dataset/images
# Moved gya_176.png to synthetic_braille_dataset/images
# Moved gya_177.png to synthetic_braille_dataset/images
# Moved gya_178.png to synthetic_braille_dataset/images
# Moved gya_179.png to synthetic_braille_dataset/images
# Moved gya_180.png to synthetic_braille_dataset/images
# Moved gya_181.png to synthetic_braille_dataset/images
# Moved gya_182.png to synthetic_braille_dataset/images
# Moved gya_183.png to synthetic_braille_dataset/images
# Moved gya_184.png to synthetic_braille_dataset/images
# Moved gya_185.png to synthetic_braille_dataset/images
# Moved gya_186.png to synthetic_braille_dataset/images
# Moved gya_187.png to synthetic_braille_dataset/images
# Moved gya_188.png to synthetic_braille_dataset/images
# Moved gya_189.png to synthetic_braille_dataset/images
# Moved gya_190.png to synthetic_braille_dataset/images
# Moved gya_191.png to synthetic_braille_dataset/images
# Moved gya_192.png to synthetic_braille_dataset/images
# Moved gya_193.png to synthetic_braille_dataset/images
# Moved gya_194.png to synthetic_braille_dataset/images
# Moved gya_195.png to synthetic_braille_dataset/images
# Moved gya_196.png to synthetic_braille_dataset/images
# Moved gya_197.png to synthetic_braille_dataset/images
# Moved gya_198.png to synthetic_braille_dataset/images
# Moved gya_199.png to synthetic_braille_dataset/images
# Moved gya_200.png to synthetic_braille_dataset/images
# Moved gya_201.png to synthetic_braille_dataset/images
# Moved gya_202.png to synthetic_braille_dataset/images
# Moved gya_203.png to synthetic_braille_dataset/images
# Moved gya_204.png to synthetic_braille_dataset/images
# Moved gya_205.png to synthetic_braille_dataset/images
# Moved gya_206.png to synthetic_braille_dataset/images
# Moved gya_207.png to synthetic_braille_dataset/images
# Moved gya_208.png to synthetic_braille_dataset/images
# Moved gya_209.png to synthetic_braille_dataset/images
# Moved gya_210.png to synthetic_braille_dataset/images
# Moved gya_211.png to synthetic_braille_dataset/images
# Moved gya_212.png to synthetic_braille_dataset/images
# Moved gya_213.png to synthetic_braille_dataset/images
# Moved gya_214.png to synthetic_braille_dataset/images
# Moved gya_215.png to synthetic_braille_dataset/images
# Moved gya_216.png to synthetic_braille_dataset/images
# Moved gya_217.png to synthetic_braille_dataset/images
# Moved gya_218.png to synthetic_braille_dataset/images
# Moved gya_219.png to synthetic_braille_dataset/images
# Moved gya_220.png to synthetic_braille_dataset/images
# Moved gya_221.png to synthetic_braille_dataset/images
# Moved gya_222.png to synthetic_braille_dataset/images
# Moved gya_223.png to synthetic_braille_dataset/images
# Moved gya_224.png to synthetic_braille_dataset/images
# Moved gya_225.png to synthetic_braille_dataset/images
# Moved gya_226.png to synthetic_braille_dataset/images
# Moved gya_227.png to synthetic_braille_dataset/images
# Moved gya_228.png to synthetic_braille_dataset/images
# Moved gya_229.png to synthetic_braille_dataset/images
# Moved gya_230.png to synthetic_braille_dataset/images
# Moved gya_231.png to synthetic_braille_dataset/images
# Moved gya_232.png to synthetic_braille_dataset/images
# Moved gya_233.png to synthetic_braille_dataset/images
# Moved gya_234.png to synthetic_braille_dataset/images
# Moved gya_235.png to synthetic_braille_dataset/images
# Moved gya_236.png to synthetic_braille_dataset/images
# Moved gya_237.png to synthetic_braille_dataset/images
# Moved gya_238.png to synthetic_braille_dataset/images
# Moved gya_239.png to synthetic_braille_dataset/images
# Moved gya_240.png to synthetic_braille_dataset/images
# Moved gya_241.png to synthetic_braille_dataset/images
# Moved gya_242.png to synthetic_braille_dataset/images
# Moved gya_243.png to synthetic_braille_dataset/images
# Moved gya_244.png to synthetic_braille_dataset/images
# Moved gya_245.png to synthetic_braille_dataset/images
# Moved gya_246.png to synthetic_braille_dataset/images
# Moved gya_247.png to synthetic_braille_dataset/images
# Moved gya_248.png to synthetic_braille_dataset/images
# Moved gya_249.png to synthetic_braille_dataset/images

# %%
import os
import shutil
import random

# Paths
base_dir = "synthetic_braille_dataset"
img_dir = os.path.join(base_dir, "images")
label_dir = os.path.join(base_dir, "labels_yolo")

# Output split directories
splits = ["train", "test", "val"]
for s in splits:
    os.makedirs(os.path.join(base_dir, f"images/{s}"), exist_ok=True)
    os.makedirs(os.path.join(base_dir, f"labels/{s}"), exist_ok=True)

# Get all image filenames
images = [f for f in os.listdir(img_dir) if f.lower().endswith((".png", ".jpg", ".jpeg"))]
images.sort()

# Shuffle them
random.shuffle(images)

# Define split sizes
total = len(images)
train_size = int(0.8 * total)
val_size = int(0.1 * total)

train_files = images[:train_size]
val_files = images[train_size:train_size + val_size]
test_files = images[train_size + val_size:]

def move_files(file_list, split_name):
    for img_file in file_list:
        label_file = os.path.splitext(img_file)[0] + ".txt"

        # Move image
        shutil.move(
            os.path.join(img_dir, img_file),
            os.path.join(base_dir, f"images/{split_name}", img_file)
        )

        # Move label
        shutil.move(
            os.path.join(label_dir, label_file),
            os.path.join(base_dir, f"labels/{split_name}", label_file)
        )

# Move files
move_files(train_files, "train")
move_files(val_files, "val")
move_files(test_files, "test")

print("Dataset successfully split into train/test/val!")
print(f"Train: {len(train_files)} images")
print(f"Val:   {len(val_files)} images")
print(f"Test:  {len(test_files)} images")
# Out:
# Dataset successfully split into train/test/val!
# Train: 9400 images
# Val:   1175 images
# Test:  1175 images

# %%
import os

label_dir = "synthetic_braille_dataset/labels"
target = "ta2_139"

print("Exact matching files:")
for f in os.listdir(label_dir):
    if target in f:
        print(repr(f))

# Also check case-insensitive versions
print("\nCase-insensitive match:")
for f in os.listdir(label_dir):
    if f.lower() == target.lower() + ".txt":
        print("Found:", repr(f))
# Out:
# Exact matching files:
#
# Case-insensitive match:
